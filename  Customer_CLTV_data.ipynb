# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc

# %%
df = pd.read_csv("customer_acquisition_data.csv")
df['cltv']= (df['revenue'] - df['cost']) * df['conversion_rate'] / df['cost']
df.describe()
# Out:
#        customer_id        cost  conversion_rate      revenue        cltv
# count     800.0000  800.000000       800.000000   800.000000  800.000000
# mean      400.5000   13.148052         0.086305  2769.151250   27.943935
# std       231.0844    9.922337         0.059611  1259.543706   22.995767
# min         1.0000    5.246263         0.016341   500.000000    0.257355
# 25%       200.7500    5.246263         0.043822  1694.000000    5.769891
# 50%       400.5000    8.320327         0.043822  2764.000000   24.756343
# 75%       600.2500    9.546326         0.123145  3824.250000   41.939870
# max       800.0000   30.450327         0.167592  4998.000000   86.417026

# %%
print(df.isnull().sum())
# Out:
# customer_id        0
# channel            0
# cost               0
# conversion_rate    0
# revenue            0
# cltv               0
# dtype: int64

# %%
x=df.drop("cltv",axis=1)
y=df["cltv"]

# %%
x=df[["cost","conversion_rate","revenue"]]

# %%
train_test_split(x,y,test_size=0.2,random_state=42)
# Out:
# [          cost  conversion_rate  revenue
#  264  30.450327         0.016341     4469
#  615  30.450327         0.016341     2555
#  329   8.320327         0.123145     1608
#  342   8.320327         0.123145     1280
#  394  30.450327         0.016341     4779
#  ..         ...              ...      ...
#  71    8.320327         0.123145     1361
#  106   5.246263         0.043822     3338
#  270   5.246263         0.043822     2176
#  435   8.320327         0.123145     4338
#  102   5.246263         0.043822     2574
#
#  [640 rows x 3 columns],
#            cost  conversion_rate  revenue
#  696   8.320327         0.123145     2857
#  667   9.546326         0.167592     1173
#  63    9.546326         0.167592     4131
#  533   8.320327         0.123145     2472
#  66   30.450327         0.016341     2529
#  ..         ...              ...      ...
#  589   5.246263         0.043822     3097
#  798  30.450327         0.016341      813
#  744   5.246263         0.043822     1740
#  513   9.546326         0.167592      871
#  670   8.320327         0.123145     4332
#
#  [160 rows x 3 columns],
#  264     2.381995
#  615     1.354826
#  329    23.676056
#  342    18.821492
#  394     2.548360
#           ...
#  71     20.020333
#  106    27.838614
#  270    18.132385
#  435    64.081415
#  102    21.456894
#  Name: cltv, Length: 640, dtype: float64,
#  696    42.161878
#  667    20.425221
#  63     72.354926
#  533    36.463686
#  66      1.340873
#           ...
#  589    25.825532
#  798     0.419964
#  744    14.490461
#  513    15.123406
#  670    63.992612
#  Name: cltv, Length: 160, dtype: float64]

# %%
x_train
# Out:
#      customer_id       cost  conversion_rate
# 264          265  30.450327         0.016341
# 615          616  30.450327         0.016341
# 329          330   8.320327         0.123145
# 342          343   8.320327         0.123145
# 394          395  30.450327         0.016341
# ..           ...        ...              ...
# 71            72   8.320327         0.123145
# 106          107   5.246263         0.043822
# 270          271   5.246263         0.043822
# 435          436   8.320327         0.123145
# 102          103   5.246263         0.043822
#
# [640 rows x 3 columns]

# %%
x_test
# Out:
#      customer_id       cost  conversion_rate
# 696          697   8.320327         0.123145
# 667          668   9.546326         0.167592
# 63            64   9.546326         0.167592
# 533          534   8.320327         0.123145
# 66            67  30.450327         0.016341
# ..           ...        ...              ...
# 589          590   5.246263         0.043822
# 798          799  30.450327         0.016341
# 744          745   5.246263         0.043822
# 513          514   9.546326         0.167592
# 670          671   8.320327         0.123145
#
# [160 rows x 3 columns]

# %%
y_train
# Out:
# 264    4469
# 615    2555
# 329    1608
# 342    1280
# 394    4779
#        ...
# 71     1361
# 106    3338
# 270    2176
# 435    4338
# 102    2574
# Name: revenue, Length: 640, dtype: int64

# %%
y_test
# Out:
# 696    2857
# 667    1173
# 63     4131
# 533    2472
# 66     2529
#        ...
# 589    3097
# 798     813
# 744    1740
# 513     871
# 670    4332
# Name: revenue, Length: 160, dtype: int64

# %%
model=LinearRegression()

# %%
model.fit (x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse =mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)
print ("mean square error:", mse)
print (r2)
# Out:
# mean square error: 1686683.9139380394
# -0.023412701358792365

# %%
print(y_pred)
# Out:
# [2837.90910645 2754.38072271 2571.09698668 2788.44677371 2782.3343833
#  2740.42202758 2866.61910904 2910.31589379 2782.60156286 2765.08113187
#  2571.70388646 2849.09336    2819.39866291 2647.03912306 2651.20775872
#  2882.16939846 2836.34846445 2741.10859023 2947.41112569 2921.92133458
#  2826.37801047 2787.23297413 2950.37127981 2980.41281932 2735.94994203
#  2635.81147698 2705.60495262 2955.60427283 2778.35326434 2934.59188532
#  2827.54841752 2785.97578203 2727.37368213 2668.20095279 2638.54252603
#  2768.60479325 2972.294017   2672.7527012  3003.17156138 2986.48181721
#  2804.48622557 2838.16916381 2604.77992492 2860.32100608 2732.53233033
#  2786.01917456 2890.66599549 2943.16282717 2809.99171619 2924.34893374
#  2842.03966762 2659.78401861 2964.40431976 2850.83971455 2728.66714457
#  2663.64920437 2897.64534306 2727.75679489 2821.70852471 2812.60502789
#  2772.66737922 2846.10225359 2960.38512631 2854.48111328 2696.80490569
#  2889.68130099 2641.57702497 3000.44051233 2660.31125554 2578.07633424
#  2792.08817244 2684.97035982 2793.22230915 2561.99348985 2561.38659006
#  2822.69321922 2872.38465703 2909.10209421 2732.22888044 2934.66623014
#  2892.18324496 2803.19808117 2784.15508267 2575.34528519 2917.67303607
#  2864.30924723 2790.49126011 2710.15670103 2736.25339193 2581.11083318
#  2956.8180724  2843.67465444 2711.9774004  2671.23545173 2952.19197917
#  2811.20551577 2975.55762102 2991.10791044 2778.69298457 2854.29540073
#  2599.01437693 2757.79833441 2791.74133002 2798.72067758 2784.68763763
#  2613.88342174 2733.52234288 2858.54369925 2689.82555813 2872.99155682
#  2755.67418515 2708.25633881 2787.79648139 2764.65994462 2980.10936943
#  2660.08746851 2919.72284051 2997.40601339 2615.40067121 2698.01870527
#  2647.86980988 2880.0452492  2798.11377779 2979.80591954 2825.34992344
#  2839.38296339 2941.6455777  2771.10673722 2843.02436212 2961.36982082
#  2752.86347324 2851.44661433 2786.2048871  2835.4815073  2853.94855831
#  2915.17109209 2781.99466307 2857.58995704 2822.12971196 2886.41769697
#  2825.65337334 2923.06078934 2908.19174453 2692.86005707 2763.74959494
#  2767.50873102 2582.62808265 2860.55011116 2824.55731111 2925.25928342
#  2746.18757557 2762.23234547 2986.25271213 2862.18509798 2919.79718533
#  2940.3574333  3004.45970578 2987.39216689 2707.64943902 2830.0194092 ]

# %%
accuracy = accuracy_score(y_test, y_pred)
print ("Accuracy:",  accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0
